# %% [markdown]
# # Pandas <hr style="border:3.5px solid rgba(41, 225, 106, 0.76)"></hr>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Data Frame

# %%
data = {
    "Name":['Henry','Owen','Ava'],
    "Age":[22,35,58],
    "Sex":['M','M','F'],
}

# %%
df = pd.DataFrame(data)
df
# Out:
#     Name  Age Sex
# 0  Henry   22   M
# 1   Owen   35   M
# 2    Ava   58   F

# %% [markdown]
# # Series

# %%
df['Name']
# Out:
# 0    Henry
# 1     Owen
# 2      Ava
# Name: Name, dtype: object

# %%
df['Age']
# Out:
# 0    22
# 1    35
# 2    58
# Name: Age, dtype: int64

# %%
df['Sex']
# Out:
# 0    M
# 1    M
# 2    F
# Name: Sex, dtype: object

# %% [markdown]
# # Descriptive Statistics

# %%
resistance = np.array([
    [10.6,9.1,9.3,9.8, 0.5,10.4,9.5,11,3,10.4,9.8],
    [10.1,11,9.1,9.2,10.8,20,9.9,9.2,9.1,9.1,np.nan]
    ]).T
resistance
# Out:
# array([[10.6, 10.1],
#        [ 9.1, 11. ],
#        [ 9.3,  9.1],
#        [ 9.8,  9.2],
#        [ 0.5, 10.8],
#        [10.4, 20. ],
#        [ 9.5,  9.9],
#        [11. ,  9.2],
#        [ 3. ,  9.1],
#        [10.4,  9.1],
#        [ 9.8,  nan]])

# %%
df = pd.DataFrame(resistance, columns=['Jaguar', 'Panther'])
df
# Out:
#     Jaguar  Panther
# 0     10.6     10.1
# 1      9.1     11.0
# 2      9.3      9.1
# 3      9.8      9.2
# 4      0.5     10.8
# 5     10.4     20.0
# 6      9.5      9.9
# 7     11.0      9.2
# 8      3.0      9.1
# 9     10.4      9.1
# 10     9.8      NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Jaguar   11 non-null     float64
#  1   Panther  10 non-null     float64
# dtypes: float64(2)
# memory usage: 308.0 bytes

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.describe()
# Out:
#           Jaguar    Panther
# count  11.000000  10.000000
# mean    8.490909  10.750000
# std     3.427960   3.329081
# min     0.500000   9.100000
# 25%     9.200000   9.125000
# 50%     9.800000   9.550000
# 75%    10.400000  10.625000
# max    11.000000  20.000000

# %%
jag_median = df['Jaguar'].median()
pan_median = df['Panther'].median()

print(f'jaguar_median = {jag_median:.2f} ohms')
print(f'panther_median = {pan_median:.2f} ohms')
# Out:
# jaguar_median = 9.80 ohms
# panther_median = 9.55 ohms

# %%
jag_mode = df['Jaguar'].mode()
pan_mode = df['Panther'].mode()

# %%
jag_mode
# Out:
# 0     9.8
# 1    10.4
# Name: Jaguar, dtype: float64

# %%
jag_mode.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 2 entries, 0 to 1
# Series name: Jaguar
# Non-Null Count  Dtype
# --------------  -----
# 2 non-null      float64
# dtypes: float64(1)
# memory usage: 148.0 bytes

# %%
type(jag_mode)
# Out:
# pandas.core.series.Series

# %%
print('Jaguar Mode:')
for i in jag_mode:
    print(i)
# Out:
# Jaguar Mode:
# 9.8
# 10.4

# %%
print('Panther Mode:')
for i in pan_mode:
    print(i)
# Out:
# Panther Mode:
# 9.1

# %%
Q1 = df['Jaguar'].quantile(0.25)
Q3 = df['Jaguar'].quantile(0.75)

print(f'Jaguar IQR = {Q3-Q1:.2f} ohms')
# Out:
# Jaguar IQR = 1.20 ohms

# %%
Q1 = df['Panther'].quantile(0.25)
Q3 = df['Panther'].quantile(0.75)

print(f'Panther IQR = {Q3 - Q1:.2f} ohms')
# Out:
# Panther IQR = 1.50 ohms

# %% [markdown]
# # Bar Chart

# %%
jag_mean = df['Jaguar'].mean()
pan_mean = df['Panther'].mean()

plt.figure(figsize=(7,4))
bars = plt.bar(['Jaguar','Panther'], 
               [jag_mean, pan_mean], 
               color='#126782')

plt.title('Average Resistance by Machine')
plt.ylabel('Resistance (ohms)')

plt.bar_label(bars, padding=3)
plt.margins(y=0.1)
plt.show()

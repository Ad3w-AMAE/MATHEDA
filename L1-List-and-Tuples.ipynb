# %% [markdown]
# # List and Tuples <hr style="border:3.5px solid rgba(41, 225, 106, 0.76)"></hr>

# %% [markdown]
# <b>Cyrus James F. Lozada</b>
# <br>Computer Engineering

# %% [markdown]
# # Create a list

# %%
numbers = [1, 2, 3, 4, 5]

# %%
fruits = ['apple', 'banana', 'grape', 'orange', 'mango']

# %%
'apple' in fruits
# Out:
# True

# %%
mixed_list = [9, 'nein',8.9, True, 'ja', 7]
mixed_list
# Out:
# [9, 'nein', 8.9, True, 'ja', 7]

# %% [markdown]
# # indexing

# %%
fruits.append('kiwi')

# %% [markdown]
# # removing

# %%
fruits = ['apple', 'rokaka', 'orange']
fruits
# Out:
# ['apple', 'rokaka', 'orange']

# %%
fruits.pop(0)
# Out:
# 'apple'

# %% [markdown]
# # sort and sorted

# %%
numbers = [1,4,3,5]
numbers
# Out:
# [1, 4, 5, 5]

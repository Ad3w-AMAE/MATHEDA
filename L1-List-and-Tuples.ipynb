# %% [markdown]
# # List and Tuples <hr style="border:3.5px solid rgba(41, 225, 106, 0.76)"></hr>

# %% [markdown]
# <b>Cyrus James F. Lozada</b>
# <br>Computer Engineering

# %% [markdown]
# # Create a list

# %%
numbers = [1, 2, 3, 4, 5]

# %%
fruits = ['apple', 'banana', 'grape', 'orange', 'mango']

# %%
'apple' in fruits
# Out:
# True

# %%
mixed_list = [9, 'nein',8.9, True, 'ja', 7]
mixed_list
# Out:
# [9, 'nein', 8.9, True, 'ja', 7]

# %% [markdown]
# # Indexing

# %%
fruits = ['apple', 'banana', 'grape', 'orange', 'mango']
fruits
# Out:
# ['apple', 'banana', 'grape', 'orange', 'mango']

# %%
fruits[0] = 'kiwi'
fruits
# Out:
# ['kiwi', 'banana', 'grape', 'orange', 'mango']

# %%
fruits.append('guava')
fruits
# Out:
# ['kiwi', 'banana', 'grape', 'orange', 'mango', 'guava']

# %%
fruits = ['apple', 'banana', 'grape', 'orange', 'mango']
fruits
# Out:
# ['apple', 'banana', 'grape', 'orange', 'mango']

# %%
fruits.insert(1, 'blueberry')
fruits
# Out:
# ['apple', 'blueberry', 'banana', 'grape', 'orange', 'mango']

# %% [markdown]
# # Removing

# %%
fruits = ['apple', 'blueberry', 'orange']
fruits
# Out:
# ['apple', 'blueberry', 'orange']

# %%
'apple' in fruits
# Out:
# True

# %%
'strawberry' in fruits
# Out:
# False

# %%
fruits.pop(0)
# Out:
# 'apple'

# %%
fruits
# Out:
# ['blueberry', 'orange']

# %% [markdown]
# # Sort and Sorted

# %%
numbers = [1,4,3,5]
numbers
# Out:
# [1, 4, 3, 5]

# %%
sorted(numbers)
# Out:
# [1, 3, 4, 5]

# %%
sorted(numbers,reverse=True)
# Out:
# [5, 4, 3, 1]

# %%
numbers.sort(reverse=True)
numbers
# Out:
# [5, 4, 3, 1]

# %% [markdown]
# # Slicing

# %%
chars = ['a','b','c','d','f']
chars
# Out:
# ['a', 'b', 'c', 'd', 'f']

# %%
len(chars)
# Out:
# 5

# %%
chars[1:4]
# Out:
# ['b', 'c', 'd']

# %% [markdown]
# # Tuple

# %%
my_tuple = (1,2,3,4,5)
my_tuple
# Out:
# (1, 2, 3, 4, 5)

# %%
type(my_tuple)
# Out:
# tuple

# %%
len(my_tuple)
# Out:
# 5

# %%
my_tuple[1:3]
# Out:
# (2, 3)

# %%
my_tuple[2]
# Out:
# 3
